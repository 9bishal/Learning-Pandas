# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name":['Harry', 'Rohan', 'Skillf', 'Shubh'],
    "marks":[92,34, 24, 17],
    "city":['Rampur','Bareilly', 'Andra', 'Antartica']
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks       city
# 0   Harry     92     Rampur
# 1   Rohan     34   Bareilly
# 2  Skillf     24      Andra
# 3   Shubh     17  Antartica

# %%
#to see the top most data
df.head(2)
# Out:
#     name  marks      city
# 0  Harry     92    Rampur
# 1  Rohan     34  Bareilly

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   marks   4 non-null      int64
#  2   city    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
#the numerical data are shown in details, like marks
df.describe()
# Out:
#           marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %%
#to convert into the csv file
df.to_csv('friends.csv')

# %%
#to hide the index
df.to_csv('friends_index_false.csv', index=False)

# %%
#to see the last most data
df.tail(1)
# Out:
#     name  marks       city
# 3  Shubh     17  Antartica

# %%
read=pd.read_csv('demo.csv')

# %%
read
# Out:
#      name  marks       city
# 0   Harry     92     Rampur
# 1   Rohan     34    Kolkata
# 2  Skillf     24   Bareilly
# 3   Shubh     17  Antartica

# %%
# to read only the particular row like name, city etc
read['name']
# Out:
# 0     Harry
# 1     Rohan
# 2    Skillf
# 3     Shubh
# Name: name, dtype: object

# %%
# we even can read the data in the particular index like:

read['name'][0]
# Out:
# 'Harry'

# %%
read['name'][0]='Harry'
# Out:
# /var/folders/yy/dttrjnps6cg07nj84419gtmw0000gn/T/ipykernel_16937/454520273.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read['name'][0]='Harry'

# %%
# even can change the data,
read['marks'][0]=99
# although it is showing the warning, but the code has been  updated!!
# Out:
# /var/folders/yy/dttrjnps6cg07nj84419gtmw0000gn/T/ipykernel_16937/2093934311.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read['marks'][0]=99
# ...

# %%
read
# Out:
#      name  marks       city
# 0   Harry     99     Rampur
# 1   Rohan     34    Kolkata
# 2  Skillf     24   Bareilly
# 3   Shubh     17  Antartica

# %%
#to convert in to a csv file
read.to_csv('read1.csv', index=False)

# %%
#it also allow to custom index
read.index=['first', 'Second','Third', 'Fourt']

# %%
read
# Out:
#           name  marks       city
# first    Harry     99     Rampur
# Second   Rohan     34    Kolkata
# Third   Skillf     24   Bareilly
# Fourt    Shubh     17  Antartica

# %%
#creating a data frame in the form of row and columns
newdf =pd.DataFrame(np.random.rand(334,5), index=np.arange(334))

# %%
#printning the data frame
newdf
# Out:
#             0         1         2         3         4
# 0    0.449980  0.173804  0.406991  0.750502  0.288611
# 1    0.565045  0.875446  0.675996  0.800321  0.148256
# 2    0.503652  0.643002  0.746705  0.449030  0.359206
# 3    0.303958  0.981712  0.485845  0.456453  0.751505
# 4    0.091031  0.772639  0.802083  0.144733  0.186428
# ..        ...       ...       ...       ...       ...
# 329  0.691870  0.392796  0.493666  0.318807  0.147284
# 330  0.642040  0.771727  0.462133  0.317996  0.563462
# 331  0.978465  0.377199  0.594443  0.646245  0.683017
# 332  0.628358  0.283826  0.438093  0.017947  0.361380
# 333  0.175887  0.282770  0.222401  0.140203  0.776492
#
# [334 rows x 5 columns]

# %%
#to know the type 
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.492066    0.505379    0.493094    0.499763    0.507934
# std      0.292007    0.285162    0.289363    0.294407    0.287871
# min      0.000671    0.003509    0.001296    0.001846    0.000617
# 25%      0.235597    0.245240    0.239539    0.236890    0.276226
# 50%      0.479619    0.521833    0.485642    0.507280    0.516877
# 75%      0.747116    0.755636    0.745863    0.768148    0.771308
# max      0.999851    0.997532    0.998188    0.999079    0.998178

# %%
#to get the info about the df
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.449980  0.173804  0.406991  0.750502  0.288611
# 1  0.565045  0.875446  0.675996  0.800321  0.148256
# 2  0.503652  0.643002  0.746705  0.449030  0.359206
# 3  0.303958  0.981712  0.485845  0.456453  0.751505
# 4  0.091031  0.772639  0.802083  0.144733  0.186428

# %%
#to know the data type
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf[0][0]="Bishal Shah"
# Out:
# /var/folders/yy/dttrjnps6cg07nj84419gtmw0000gn/T/ipykernel_16937/674700252.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newdf[0][0]
# 4    0.091031  0.772639  0.802083  0.144733  0.186428
# 3    0.303958  0.981712  0.485845  0.456453  0.751505
# 2    0.503652  0.643002  0.746705  0.449030  0.359206
# 1    0.565045  0.875446  0.675996  0.800321  0.148256
# 0    0.695221  0.173804  0.406991  0.750502  0.288611
#
# [334 rows x 5 columns]

# %%
#to reverse sort the columns
newdf.sort_index(axis=1, ascending=False)
# Out:
#             4         3         2         1         0
# 0    0.288611  0.750502  0.406991  0.173804  0.695221
# 1    0.148256  0.800321  0.675996  0.875446  0.565045
# 2    0.359206  0.449030  0.746705  0.643002  0.503652
# 3    0.751505  0.456453  0.485845  0.981712  0.303958
# 4    0.186428  0.144733  0.802083  0.772639  0.091031
# ..        ...       ...       ...       ...       ...
# 329  0.147284  0.318807  0.493666  0.392796   0.69187
# 330  0.563462  0.317996  0.462133  0.771727   0.64204
# 331  0.683017  0.646245  0.594443  0.377199  0.978465
# 332  0.361380  0.017947  0.438093  0.283826  0.628358
# 333  0.776492  0.140203  0.222401  0.282770  0.175887
#
# [334 rows x 5 columns]

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.695221  0.173804  0.406991  0.750502  0.288611
# 1    0.565045  0.875446  0.675996  0.800321  0.148256
# 2    0.503652  0.643002  0.746705  0.449030  0.359206
# 3    0.303958  0.981712  0.485845  0.456453  0.751505
# 4    0.091031  0.772639  0.802083  0.144733  0.186428
# ..        ...       ...       ...       ...       ...
# 329   0.69187  0.392796  0.493666  0.318807  0.147284
# 330   0.64204  0.771727  0.462133  0.317996  0.563462
# 331  0.978465  0.377199  0.594443  0.646245  0.683017
# 332  0.628358  0.283826  0.438093  0.017947  0.361380
# 333  0.175887  0.282770  0.222401  0.140203  0.776492
#
# [334 rows x 5 columns]

# %%
#to access all the elements at 0th column
newdf[0]
# Out:
# 0      0.695221
# 1      0.565045
# 2      0.503652
# 3      0.303958
# 4      0.091031
#          ...
# 329     0.69187
# 330     0.64204
# 331    0.978465
# 332    0.628358
# 333    0.175887
# Name: 0, Length: 334, dtype: object

# %%
#inorder to remove the warning, we use .lock[0][0] for the replacement of the value
newdf.loc[0,0]=11

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0        11  0.173804  0.406991  0.750502  0.288611
# 1  0.565045  0.875446  0.675996  0.800321  0.148256
# 2  0.503652  0.643002  0.746705  0.449030  0.359206
# 3  0.303958  0.981712  0.485845  0.456453  0.751505
# 4  0.091031  0.772639  0.802083  0.144733  0.186428

# %%
#to set the columns name
newdf.columns=list("ABCDE")

# %%
newdf
# Out:
#             A         B         C         D         E
# 0          11  0.173804  0.406991  0.750502  0.288611
# 1    0.565045  0.875446  0.675996  0.800321  0.148256
# 2    0.503652  0.643002  0.746705  0.449030  0.359206
# 3    0.303958  0.981712  0.485845  0.456453  0.751505
# 4    0.091031  0.772639  0.802083  0.144733  0.186428
# ..        ...       ...       ...       ...       ...
# 329   0.69187  0.392796  0.493666  0.318807  0.147284
# 330   0.64204  0.771727  0.462133  0.317996  0.563462
# 331  0.978465  0.377199  0.594443  0.646245  0.683017
# 332  0.628358  0.283826  0.438093  0.017947  0.361380
# 333  0.175887  0.282770  0.222401  0.140203  0.776492
#
# [334 rows x 5 columns]

# %%
#so now if we want to access 11, we need to [0,'A']

# %%
newdf
# Out:
#             A         B         C         D         E
# 0          11  0.173804  0.406991  0.750502  0.288611
# 1    0.565045  0.875446  0.675996  0.800321  0.148256
# 2    0.503652  0.643002  0.746705  0.449030  0.359206
# 3    0.303958  0.981712  0.485845  0.456453  0.751505
# 4    0.091031  0.772639  0.802083  0.144733  0.186428
# ..        ...       ...       ...       ...       ...
# 329   0.69187  0.392796  0.493666  0.318807  0.147284
# 330   0.64204  0.771727  0.462133  0.317996  0.563462
# 331  0.978465  0.377199  0.594443  0.646245  0.683017
# 332  0.628358  0.283826  0.438093  0.017947  0.361380
# 333  0.175887  0.282770  0.222401  0.140203  0.776492
#
# [334 rows x 5 columns]

# %%
#to remove the last column
newdf.drop(0,axis=0)
# Out:
#             A         B         C         D         E
# 1    0.565045  0.875446  0.675996  0.800321  0.148256
# 2    0.503652  0.643002  0.746705  0.449030  0.359206
# 3    0.303958  0.981712  0.485845  0.456453  0.751505
# 4    0.091031  0.772639  0.802083  0.144733  0.186428
# 5    0.422088  0.899371  0.021610  0.587218  0.471237
# ..        ...       ...       ...       ...       ...
# 329   0.69187  0.392796  0.493666  0.318807  0.147284
# 330   0.64204  0.771727  0.462133  0.317996  0.563462
# 331  0.978465  0.377199  0.594443  0.646245  0.683017
# 332  0.628358  0.283826  0.438093  0.017947  0.361380
# 333  0.175887  0.282770  0.222401  0.140203  0.776492
#
# [333 rows x 5 columns]

# %%
newdf.loc[0,'A']=90

# %%
newdf
# Out:
#             A         B         C         D         E
# 0          90  0.173804  0.406991  0.750502  0.288611
# 1    0.565045  0.875446  0.675996  0.800321  0.148256
# 2    0.503652  0.643002  0.746705  0.449030  0.359206
# 3    0.303958  0.981712  0.485845  0.456453  0.751505
# 4    0.091031  0.772639  0.802083  0.144733  0.186428
# ..        ...       ...       ...       ...       ...
# 329   0.69187  0.392796  0.493666  0.318807  0.147284
# 330   0.64204  0.771727  0.462133  0.317996  0.563462
# 331  0.978465  0.377199  0.594443  0.646245  0.683017
# 332  0.628358  0.283826  0.438093  0.017947  0.361380
# 333  0.175887  0.282770  0.222401  0.140203  0.776492
#
# [334 rows x 5 columns]

# %%
newdf.loc[0,'A']=901
newdf
# Out:
#             A         B         C         D         E
# 0         901  0.173804  0.406991  0.750502  0.288611
# 1    0.565045  0.875446  0.675996  0.800321  0.148256
# 2    0.503652  0.643002  0.746705  0.449030  0.359206
# 3    0.303958  0.981712  0.485845  0.456453  0.751505
# 4    0.091031  0.772639  0.802083  0.144733  0.186428
# ..        ...       ...       ...       ...       ...
# 329   0.69187  0.392796  0.493666  0.318807  0.147284
# 330   0.64204  0.771727  0.462133  0.317996  0.563462
# 331  0.978465  0.377199  0.594443  0.646245  0.683017
# 332  0.628358  0.283826  0.438093  0.017947  0.361380
# 333  0.175887  0.282770  0.222401  0.140203  0.776492
#
# [334 rows x 5 columns]

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0       901  0.173804  0.406991  0.750502  0.288611
# 1  0.565045  0.875446  0.675996  0.800321  0.148256
# 2  0.503652  0.643002  0.746705  0.449030  0.359206
# 3  0.303958  0.981712  0.485845  0.456453  0.751505
# 4  0.091031  0.772639  0.802083  0.144733  0.186428

# %%
newdf.drop(1, axis=0)#removed the data of  1st row
# Out:
#             A         B         C         D         E
# 0         901  0.173804  0.406991  0.750502  0.288611
# 2    0.503652  0.643002  0.746705  0.449030  0.359206
# 3    0.303958  0.981712  0.485845  0.456453  0.751505
# 4    0.091031  0.772639  0.802083  0.144733  0.186428
# 5    0.422088  0.899371  0.021610  0.587218  0.471237
# ..        ...       ...       ...       ...       ...
# 329   0.69187  0.392796  0.493666  0.318807  0.147284
# 330   0.64204  0.771727  0.462133  0.317996  0.563462
# 331  0.978465  0.377199  0.594443  0.646245  0.683017
# 332  0.628358  0.283826  0.438093  0.017947  0.361380
# 333  0.175887  0.282770  0.222401  0.140203  0.776492
#
# [333 rows x 5 columns]

# %%
newdf.drop(3,axis=0)#removed the data of  3rd  row
# Out:
#             A         B         C         D         E
# 0         901  0.173804  0.406991  0.750502  0.288611
# 1    0.565045  0.875446  0.675996  0.800321  0.148256
# 2    0.503652  0.643002  0.746705  0.449030  0.359206
# 4    0.091031  0.772639  0.802083  0.144733  0.186428
# 5    0.422088  0.899371  0.021610  0.587218  0.471237
# ..        ...       ...       ...       ...       ...
# 329   0.69187  0.392796  0.493666  0.318807  0.147284
# 330   0.64204  0.771727  0.462133  0.317996  0.563462
# 331  0.978465  0.377199  0.594443  0.646245  0.683017
# 332  0.628358  0.283826  0.438093  0.017947  0.361380
# 333  0.175887  0.282770  0.222401  0.140203  0.776492
#
# [333 rows x 5 columns]

# %%
newdf.drop('D', axis=1)#the axis=1 denotes column and 0 denotes row
newdf1=newdf.drop('A', axis=1)#the axis=1 denotes column and 0 denotes row
newdf1
# Out:
#             B         C         D         E
# 0    0.173804  0.406991  0.750502  0.288611
# 1    0.875446  0.675996  0.800321  0.148256
# 2    0.643002  0.746705  0.449030  0.359206
# 3    0.981712  0.485845  0.456453  0.751505
# 4    0.772639  0.802083  0.144733  0.186428
# ..        ...       ...       ...       ...
# 329  0.392796  0.493666  0.318807  0.147284
# 330  0.771727  0.462133  0.317996  0.563462
# 331  0.377199  0.594443  0.646245  0.683017
# 332  0.283826  0.438093  0.017947  0.361380
# 333  0.282770  0.222401  0.140203  0.776492
#
# [334 rows x 4 columns]

# %%
newdf.head(3)
# Out:
#           A         B         C         D         E
# 0       901  0.173804  0.406991  0.750502  0.288611
# 1  0.565045  0.875446  0.675996  0.800321  0.148256
# 2  0.503652  0.643002  0.746705  0.449030  0.359206

# %%
newdf.loc[1,'A']=90

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0       901  0.173804  0.406991  0.750502  0.288611
# 1        90  0.875446  0.675996  0.800321  0.148256
# 2  0.503652  0.643002  0.746705  0.449030  0.359206
# 3  0.303958  0.981712  0.485845  0.456453  0.751505
# 4  0.091031  0.772639  0.802083  0.144733  0.186428

# %%
newdf.drop(0, axis=0)#0->row & 1-> columns
# Out:
#             A         B         C         D         E
# 1          90  0.875446  0.675996  0.800321  0.148256
# 2    0.503652  0.643002  0.746705  0.449030  0.359206
# 3    0.303958  0.981712  0.485845  0.456453  0.751505
# 4    0.091031  0.772639  0.802083  0.144733  0.186428
# 5    0.422088  0.899371  0.021610  0.587218  0.471237
# ..        ...       ...       ...       ...       ...
# 329   0.69187  0.392796  0.493666  0.318807  0.147284
# 330   0.64204  0.771727  0.462133  0.317996  0.563462
# 331  0.978465  0.377199  0.594443  0.646245  0.683017
# 332  0.628358  0.283826  0.438093  0.017947  0.361380
# 333  0.175887  0.282770  0.222401  0.140203  0.776492
#
# [333 rows x 5 columns]

# %%
newdf
# Out:
#             A         B         C         D         E
# 0         901  0.173804  0.406991  0.750502  0.288611
# 1          90  0.875446  0.675996  0.800321  0.148256
# 2    0.503652  0.643002  0.746705  0.449030  0.359206
# 3    0.303958  0.981712  0.485845  0.456453  0.751505
# 4    0.091031  0.772639  0.802083  0.144733  0.186428
# ..        ...       ...       ...       ...       ...
# 329   0.69187  0.392796  0.493666  0.318807  0.147284
# 330   0.64204  0.771727  0.462133  0.317996  0.563462
# 331  0.978465  0.377199  0.594443  0.646245  0.683017
# 332  0.628358  0.283826  0.438093  0.017947  0.361380
# 333  0.175887  0.282770  0.222401  0.140203  0.776492
#
# [334 rows x 5 columns]

# %%
newdf.loc[[1,2,3,4,5,36],['C','D','E']] #to access particular no. of rows and columns
# Out:
#            C         D         E
# 1   0.675996  0.800321  0.148256
# 2   0.746705  0.449030  0.359206
# 3   0.485845  0.456453  0.751505
# 4   0.802083  0.144733  0.186428
# 5   0.021610  0.587218  0.471237
# 36  0.231017  0.982288  0.122172

# %%
newdf
# Out:
#             A         B         C         D         E
# 0         901  0.173804  0.406991  0.750502  0.288611
# 1          90  0.875446  0.675996  0.800321  0.148256
# 2    0.503652  0.643002  0.746705  0.449030  0.359206
# 3    0.303958  0.981712  0.485845  0.456453  0.751505
# 4    0.091031  0.772639  0.802083  0.144733  0.186428
# ..        ...       ...       ...       ...       ...
# 329   0.69187  0.392796  0.493666  0.318807  0.147284
# 330   0.64204  0.771727  0.462133  0.317996  0.563462
# 331  0.978465  0.377199  0.594443  0.646245  0.683017
# 332  0.628358  0.283826  0.438093  0.017947  0.361380
# 333  0.175887  0.282770  0.222401  0.140203  0.776492
#
# [334 rows x 5 columns]

# %%
newdf.loc[:,['A']]  #to access all the rows of A
# Out:
#             A
# 0         901
# 1          90
# 2    0.503652
# 3    0.303958
# 4    0.091031
# ..        ...
# 329   0.69187
# 330   0.64204
# 331  0.978465
# 332  0.628358
# 333  0.175887
#
# [334 rows x 1 columns]

# %%
newdf.loc[[7],:] #to access all the columns of 7
# Out:
#           A         B         C         D         E
# 7  0.833987  0.196484  0.230091  0.121334  0.278705

# %%
newdf.loc[(newdf['A']>0.9)]
# Out:
#             A         B         C         D         E
# 0         901  0.173804  0.406991  0.750502  0.288611
# 1          90  0.875446  0.675996  0.800321  0.148256
# 13   0.944981  0.077851  0.934153  0.541974  0.410949
# 22    0.93389  0.727671  0.777677  0.713432  0.171049
# 23   0.908393  0.783638  0.218035  0.864086  0.285184
# 54   0.947876  0.128257  0.202510  0.230705  0.054073
# 56   0.956497  0.204445  0.454313  0.023526  0.474938
# 58    0.95959  0.095151  0.784380  0.848061  0.051054
# 74   0.997337  0.745055  0.285591  0.694313  0.521438
# 80   0.995805  0.839604  0.214493  0.898456  0.914772
# 83   0.981269  0.415096  0.922712  0.557244  0.537661
# 87   0.960808  0.801315  0.626710  0.112625  0.116210
# 96   0.906174  0.534368  0.065923  0.432688  0.439254
# 97   0.937556  0.681125  0.492244  0.028659  0.515999
# 109  0.926272  0.738263  0.677377  0.615681  0.964704
# 122  0.946993  0.751509  0.994509  0.870744  0.283109
# ...

# %%
newdf
# Out:
#             A         B         C         D         E
# 0         901  0.173804  0.406991  0.750502  0.288611
# 1          90  0.875446  0.675996  0.800321  0.148256
# 2    0.503652  0.643002  0.746705  0.449030  0.359206
# 3    0.303958  0.981712  0.485845  0.456453  0.751505
# 4    0.091031  0.772639  0.802083  0.144733  0.186428
# ..        ...       ...       ...       ...       ...
# 329   0.69187  0.392796  0.493666  0.318807  0.147284
# 330   0.64204  0.771727  0.462133  0.317996  0.563462
# 331  0.978465  0.377199  0.594443  0.646245  0.683017
# 332  0.628358  0.283826  0.438093  0.017947  0.361380
# 333  0.175887  0.282770  0.222401  0.140203  0.776492
#
# [334 rows x 5 columns]

# %%
newdf.iloc[0,3]#when we only know the index | if we know the column value we use loc
# Out:
# np.float64(0.7505024378515764)

# %%
newdf.iloc[[0,6],:]
# Out:
#           A         B         C         D         E
# 0       901  0.173804  0.406991  0.750502  0.288611
# 6  0.765555  0.555178  0.758579  0.355582  0.380097

# %%
newdf.iloc[:,[0,1]]
# Out:
#             A         B
# 0         901  0.173804
# 1          90  0.875446
# 2    0.503652  0.643002
# 3    0.303958  0.981712
# 4    0.091031  0.772639
# ..        ...       ...
# 329   0.69187  0.392796
# 330   0.64204  0.771727
# 331  0.978465  0.377199
# 332  0.628358  0.283826
# 333  0.175887  0.282770
#
# [334 rows x 2 columns]

# %%
newdf.drop(0, axis=0) # also another way without name of the column
newdf.drop([0])
# Out:
#             A         B         C         D         E
# 
# 2        6  0.758579  0.355582  0.380097
# 3        7  0.230091  0.121334  0.278705
# 4        8  0.132626  0.843076  0.857242
# ..     ...       ...       ...       ...
# 325    329  0.493666  0.318807  0.147284
# 326    330  0.462133  0.317996  0.563462
# 327    331  0.594443  0.646245  0.683017
# 328    332  0.438093  0.017947  0.361380
# 329    333  0.222401  0.140203  0.776492
#
# [330 rows x 4 columns]

# %%
newdf.reset_index(drop=True, inplace=True)  # to remove the 'index' columns

# %%
newdf
# Out:
#             C         D         E
# 0    0.406991  0.750502  0.288611
# 1    0.021610  0.587218  0.471237
# 2    0.758579  0.355582  0.380097
# 3    0.230091  0.121334  0.278705
# 4    0.132626  0.843076  0.857242
# ..        ...       ...       ...
# 325  0.493666  0.318807  0.147284
# 326  0.462133  0.317996  0.563462
# 327  0.594443  0.646245  0.683017
# 328  0.438093  0.017947  0.361380
# 329  0.222401  0.140203  0.776492
#
# [330 rows x 3 columns]

# %%
newdf.loc[:,['C']]=None
newdf
# Out:
# /var/folders/yy/dttrjnps6cg07nj84419gtmw0000gn/T/ipykernel_16937/1589854205.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'None' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   newdf.loc[:,['C']]=None
#         C         D         E
# 0    None  0.750502  0.288611
# 1    None  0.587218  0.471237
# 2    None  0.355582  0.380097
# 3    None  0.121334  0.278705
# 4    None  0.843076  0.857242
# ..    ...       ...       ...
# 325  None  0.318807  0.147284
# 326  None  0.317996  0.563462
# 327  None  0.646245  0.683017
# 328  None  0.017947  0.361380
# 329  None  0.140203  0.776492
#
# [330 rows x 3 columns]

# %%
newdf.loc[0,'D']=None
newdf
# Out:
#         C         D         E
# 0    None       NaN  0.288611
# 1    None  0.587218  0.471237
# 2    None  0.355582  0.380097
# 3    None  0.121334  0.278705
# 4    None  0.843076  0.857242
# ..    ...       ...       ...
# 325  None  0.318807  0.147284
# 326  None  0.317996  0.563462
# 327  None  0.646245  0.683017
# 328  None  0.017947  0.361380
# 329  None  0.140203  0.776492
#
# [330 rows x 3 columns]

# %%
newdf['D'].isnull()
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 325    False
# 326    False
# 327    False
# 328    False
# 329    False
# Name: D, Length: 330, dtype: bool

# %%
newdf.shape
# Out:
# (330, 3)

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   C       0 non-null      object
#  1   D       329 non-null    float64
#  2   E       330 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 7.9+ KB

# %%
df['name'].values
# Out:
# array(['Harry', 'Rohan', 'Skillf', 'Shubh'], dtype=object)

# %%
df['city'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       Rampur
# 1     Bareilly
# 2        Andra
# 3    Antartica
# Name: city, dtype: object>

# %%
newdf['D'].value_counts(dropna=0.542767)
# Out:
# D
# 0.587218    1
# 0.921204    1
# 0.923541    1
# 0.898882    1
# 0.343040    1
#            ..
# 0.565852    1
# 0.348913    1
# 0.822718    1
# 0.300370    1
# 0.140203    1
# Name: count, Length: 329, dtype: int64

# %%
newdf['D'].value_counts(dropna=0.608930)
# Out:
# D
# 0.587218    1
# 0.921204    1
# 0.923541    1
# 0.898882    1
# 0.343040    1
#            ..
# 0.565852    1
# 0.348913    1
# 0.822718    1
# 0.300370    1
# 0.140203    1
# Name: count, Length: 329, dtype: int64

# %%
df['city'].value_counts(dropna=False)
# Out:
# city
# Rampur       1
# Bareilly     1
# Andra        1
# Antartica    1
# Name: count, dtype: int64
